# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-1.1.2-cp38-cp38-win_amd64.whl (9.6 MB)
# ...
#   Using cached pytz-2020.1-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached numpy-1.19.2-cp38-cp38-win_amd64.whl (13.0 MB)
# ...

# %%
import pandas as pd

# %%
teams = pd.read_csv("teams.csv")
teams
# Out:
#                        ipl team
# 0                 Pune Warriors
# 1         Kolkata Knight Riders
# 2              Rajasthan Royals
# 3          Kochi Tuskers Kerala
# 4                 Gujarat Lions
# 5           Chennai Super Kings
# 6       Rising Pune Supergiants
# 7              Delhi Daredevils
# 8               Deccan Chargers
# 9                Delhi Capitals
# 10               Mumbai Indians
# 11          Sunrisers Hyderabad
# 12       Rising Pune Supergiant
# 13  Royal Challengers Bangalore
# 14              Kings XI Punjab

# %%
teams_home = pd.read_csv("teamwise_home_and_away.csv")
teams_home
# Out:
#                            team  home_wins  away_wins  home_matches  \
# 0        Rising Pune Supergiant          5          5             8
# 1                Mumbai Indians         58         51           101
# 2           Chennai Super Kings         51         49            89
# 3                Delhi Capitals          3          7             6
# 4           Sunrisers Hyderabad         30         28            63
# 5              Rajasthan Royals         29         46            67
# 6               Deccan Chargers         18         11            43
# 7               Kings XI Punjab         38         44            91
# 8   Royal Challengers Bangalore         35         49            85
# 9         Kolkata Knight Riders         34         58            83
# 10             Delhi Daredevils         25         42            72
# 11                Pune Warriors          6          6            20
# 12         Kochi Tuskers Kerala          2          4             7
# ...

# %%
teams.columns
# Out:
# Index(['ipl team'], dtype='object')

# %%
teams_home.columns
# Out:
# Index(['team', 'home_wins', 'away_wins', 'home_matches', 'away_matches',
#        'home_win_percentage', 'away_win_percentage'],
#       dtype='object')

# %%
match_table = pd.merge(teams, teams_home, left_on='ipl team', right_on='team')
match_table.head()
# Out:
#                 ipl team                   team  home_wins  away_wins  \
# 0          Pune Warriors          Pune Warriors          6          6
# 1  Kolkata Knight Riders  Kolkata Knight Riders         34         58
# 2       Rajasthan Royals       Rajasthan Royals         29         46
# 3   Kochi Tuskers Kerala   Kochi Tuskers Kerala          2          4
# 4          Gujarat Lions          Gujarat Lions          1         12
#
#    home_matches  away_matches  home_win_percentage  away_win_percentage
# 0            20            26            30.000000            23.076923
# 1            83            95            40.963855            61.052632
# 2            67            80            43.283582            57.500000
# 3             7             7            28.571429            57.142857
# 4            14            16             7.142857            75.000000

# %%
Links = pd .read_csv("links.csv")
Links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
Links_Small = pd.read_csv("links_small.csv")
Links_Small.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
Link = pd.merge(Links,Links_Small)
